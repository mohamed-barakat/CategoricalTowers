# %%
using CapAndHomalg
# Out:
# CapAndHomalg v1.6.3
# Imported OSCAR's components GAP and Singular_jll
# Type: ?CapAndHomalg for more information

# %%
LoadPackage( "FunctorCategories" )

# %%
q = FinQuiver( "q(A)[]" )
# Out:
# GAP: FinQuiver( "q(A)[]" )

# %%
C = PathCategory( q )
# Out:
# GAP: PathCategory( FinQuiver( "q(A)[]" ) )

# %%
B = SyntacticCategoryInDoctrines( g"IsElementaryTopos", name = g"B", category = C )
# Out:
# GAP: B

# %%
Display( B )
# Out:
# A CAP category with name B:
#
# 37 primitive operations were used to derive 239 operations for this category which algorithmically
# * IsElementaryTopos

# %%
singleton_morphism = SingletonMorphism( B.A )
# Out:
# GAP: <A monomorphism in B>

# %%
program_implemented = LambdaAbstraction( singleton_morphism, ConvertJuliaToGAP( [ B, B.A ] ) )
# Out:
# GAP: function( cat, A ) ... end

# %%
Display( program_implemented )
# Out:
# function ( cat, A )
# local node_1, node_2, node_3, node_4, node_5, node_6, node_7, node_8, node_9;
# node_1 := A;
# node_2 := IdentityMorphism( cat, node_1 );
# node_3 := [ node_2, node_2 ];
# node_4 := [ node_1, node_1 ];
# node_5 := UniversalMorphismIntoDirectProduct( cat, node_4, node_1, node_3 );
# node_6 := ClassifyingMorphismOfSubobject( cat, node_5 );
# node_7 := ExponentialOnMorphisms( cat, node_2, node_6 );
# node_8 := CartesianRightCoevaluationMorphism( cat, node_1, node_1 );
# node_9 := PreCompose( cat, node_8, node_7 );
# return node_9;
# end

# %%
svg_string = DotToSVG( DotVertexLabelledDigraph( singleton_morphism ) );

# %%
display( MIME("image/svg+xml"), GAPToJulia( svg_string ) )

# %%
Display( svg_string )
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.50.0 (20211204.2007)
#  -->
# <!-- Title: DigraphOfEvaluation Pages: 1 -->
# <svg width="440pt" height="671pt"
#  viewBox="0.00 0.00 439.50 671.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 667)">
# <title>DigraphOfEvaluation</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-667 435.5,-667 435.5,4 -4,4"/>
# <!-- 1 -->
# <g id="node1" class="node">
# <title>1</title>
# <polygon fill="none" stroke="black" points="192.5,-663 125.5,-663 125.5,-595 192.5,-595 192.5,-663"/>
# <text text-anchor="middle" x="159" y="-647.8" font-family="Times,serif" font-size="14.00">[1]</text>
# ...
